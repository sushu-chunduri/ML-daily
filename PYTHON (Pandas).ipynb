# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Series of 1-D array

# %%
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pop = pd.Series([1444 , 1393 , 323 , 278],
                index = ["India","China","USA","Indonesia"],
                name = "population_millions"
               )

# %%
print(pop)
# Out:
# India        1444
# China        1393
# USA           323
# Indonesia     278
# Name: population_millions, dtype: int64

# %%
print(pop[pop>500])
# Out:
# India    1444
# China    1393
# Name: population_millions, dtype: int64

# %%
q1 = pd.Series({"laptops":120,"phone":340,"tablets":77})
q2 = pd.Series({"phones":44,"laptops":474,"watches":73})
print(q1+q2)
# Out:
# laptops    594.0
# phone        NaN
# phones       NaN
# tablets      NaN
# watches      NaN
# dtype: float64

# %% [markdown]
# #Data frames

# %%
df = pd.DataFrame({
    "name": ["Aushu","Bill","chen","Dev","Emu"],
    "dept": ["IT","HR","IT","Finance","HR"],
    "salary":[52000,48000,47999,75000,50000],
    "city":["Delhi","Mumbai","Surat","Agra","Delhi"]
})

# %%
print(df)
# Out:
#     name     dept  salary    city
# 0  Aushu       IT   52000   Delhi
# 1   Bill       HR   48000  Mumbai
# 2   chen       IT   47999   Surat
# 3    Dev  Finance   75000    Agra
# 4    Emu       HR   50000   Delhi

# %%
print(df.shape)
# Out:
# (5, 4)

# %%
print(list(df.columns))
# Out:
# ['name', 'dept', 'salary', 'city']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   dept    5 non-null      object
#  2   salary  5 non-null      int64
#  3   city    5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#              salary
# count      5.000000
# mean   54599.800000
# std    11524.031421
# min    47999.000000
# 25%    48000.000000
# 50%    50000.000000
# 75%    52000.000000
# max    75000.000000

# %%
raw = pd.DataFrame({
    "order_id":["1001","1002","1003"],
    "amount":["2500","1800","1700"]
})

# %%
print(raw["amount"].sum())
# Out:
# 250018001700

# %%
clean = raw.copy()

# %%
clean["order_id"] = pd.to_numeric(clean["order_id"])
clean["amount"] = pd.to_numeric(clean["amount"])

# %%
print(clean.sum())
# Out:
# order_id    3006
# amount      6000
# dtype: int64

# %%
print(clean["amount"].sum())
# Out:
# 6000

# %%
df
# Out:
#     name     dept  salary    city
# 0  Aushu       IT   52000   Delhi
# 1   Bill       HR   48000  Mumbai
# 2   chen       IT   47999   Surat
# 3    Dev  Finance   75000    Agra
# 4    Emu       HR   50000   Delhi

# %%
people = df.set_index("name")

# %%
people
# Out:
#           dept  salary    city
# name
# Aushu       IT   52000   Delhi
# Bill        HR   48000  Mumbai
# chen        IT   47999   Surat
# Dev    Finance   75000    Agra
# Emu         HR   50000   Delhi

# %%
print(people.loc["Aushu"])
# Out:
# dept         IT
# salary    52000
# city      Delhi
# Name: Aushu, dtype: object

# %%
print(people.loc[["Aushu"],["salary"]])
# Out:
#        salary
# name
# Aushu   52000

# %%
print(people.iloc[0])
# Out:
# dept         IT
# salary    52000
# city      Delhi
# Name: Aushu, dtype: object

# %%
print(people.iloc[0:3],[0,2])
# Out:
#       dept  salary    city
# name
# Aushu   IT   52000   Delhi
# Bill    HR   48000  Mumbai
# chen    IT   47999   Surat [0, 2]

# %%
print(people[people["salary"]<49000])
# Out:
#      dept  salary    city
# name
# Bill   HR   48000  Mumbai
# chen   IT   47999   Surat

# %%
print(people[(people["dept"] == "IT") & (people["salary"] < 49000)])
# Out:
#      dept  salary   city
# name
# chen   IT   47999  Surat

# %%
print(people.query("dept == 'IT'"))
# Out:
#       dept  salary   city
# name
# Aushu   IT   52000  Delhi
# chen    IT   47999  Surat

# %% [markdown]
# #Missing data

# %%
messy = pd.DataFrame({
    "product":["pen","Book","Bag","lamp","Mug"],
    "price":[20,np.nan,850,1200,np.nan],
    "rating":[4.1,4.5,np.nan,4.5,3.9]
})

# %%
messy
# Out:
#   product   price  rating
# 0     pen    20.0     4.1
# 1    Book     NaN     4.5
# 2     Bag   850.0     NaN
# 3    lamp  1200.0     4.5
# 4     Mug     NaN     3.9

# %%
messy.isna().sum()
# Out:
# product    0
# price      2
# rating     1
# dtype: int64

# %%
filled  = messy.copy()

# %%
filled["price"] = filled["price"].fillna(filled["price"].mean())

# %%
filled["rating"] = filled["rating"].fillna(filled["rating"].median())

# %%
print(filled)
# Out:
#   product  price  rating
# 0     pen    4.1     4.1
# 1    Book    4.5     4.5
# 2     Bag    4.3     4.3
# 3    lamp    4.5     4.5
# 4     Mug    3.9     3.9
