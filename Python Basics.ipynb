# %% [markdown]
# Variables and data types

# %%
Name = "Sushma"
age = 20
height = 5.4
is_student = True

# %%
print(Name,age,height,is_student)
# Out:
# Sushma 20 5.4 True

# %%
type("name"),type(age),type(height),type("is_student")
# Out:
# (str, int, float, str)

# %%
Name = "Sushma"
name = str(Name)
print(name)
# Out:
# Sushma

# %% [markdown]
# Input and output

# %%
print("hello,world,from,python")
# Out:
# hello,world,from,python

# %%
name = input("Enter your name")
print(name)
# Out:
# Enter your name sushmachunduri
# sushmachunduri

# %%
a = int(input("Enter a number"))
print(a+3)
# Out:
# Enter a number 5
# 8

# %%
name = "sushma"
marks = 90
print(f"{name} has scored {marks}out of 100")
# Out:
# sushma has scored 90out of 100

# %%
print(f"percentage:{marks:1f}%")
# Out:
# percentage:90.000000%

# %% [markdown]
# Operators

# %%
a,b = 10,4
print(a+b,a-b,a*b)
# Out:
# 14 6 40

# %%
a,b = 10,2
print(a/b) # division
print(a//b)  # floor division 
print(a % b) # remainder or module operator
print(a ** b) # exponent
# Out:
# 5.0
# 5
# 0
# 100

# %% [markdown]
# Arithmetic Exampe

# %%
price = 250
quantity = 4
tax = 0.18
total = price*quantity*(1+tax)
print(total)
# Out:
# 1180.0

# %% [markdown]
# Comparison

# %%
print(10>5)
print(10 == 5)
print(10!= 5)
# Out:
# True
# False
# True

# %%
marks = 75
print(50<=marks<=100)
# Out:
# True

# %% [markdown]
# logical operation

# %%
x,y = True,False
print(x and y),print(x or y),print(not x)
# Out:
# False
# True
# False
# (None, None, None)

# %%
a = 20
has_id = True
print(age >=18 and has_id)
# Out:
# True

# %%
income = 50000
credit_score = 760

eligible= income > 30000 and credit_score >= 700
print(eligible)
# Out:
# True

# %% [markdown]
# list

# %%
numbers = [10, 20, 30, 40]
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
print(numbers[0])
# Out:
# 10

# %%
print(numbers[0:4])
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# Append and remove list

# %%
fruits = ["apple", "banana", "mango"]

# %%
print(fruits[1])
# Out:
# banana

# %%
fruits.append("orange") # add

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
fruits.remove("apple")

# %%
print(fruits)
# Out:
# ['banana', 'mango', 'orange']

# %%
nums = [1, 4, 5, 6, 8]
print(len(nums))
print(sum(nums))
print(max(nums),min(nums))
# Out:
# 5
# 24
# 8 1

# %%
nums = [2, 10, 5, 4, 1, 3]
nums.sort()

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
nums = [10, 20, 30, 40, 50]
print(nums[1:4])
# Out:
# [20, 30, 40]

# %%
print(nums[:3])
# Out:
# [10, 20, 30]

# %%
print(nums[::])
# Out:
# [10, 20, 30, 40, 50]

# %%
print(nums[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
print(nums)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(nums[-3:])
# Out:
# [30, 40, 50]

# %%
print(nums[1:4:2])
# Out:
# [20, 40]

# %% [markdown]
# loops

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2, 11, 2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
marks = [70, 80, 90]
for mark in marks:
    print(marks)
# Out:
# [70, 80, 90]
# [70, 80, 90]
# [70, 80, 90]

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5
